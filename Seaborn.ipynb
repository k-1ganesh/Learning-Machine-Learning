# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %% [markdown]
# # Loading Seaborn Datasets

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # Line Plot

# %%
x = np.arange(0,10)
y = np.random.randint(10,20,10)

df = pd.DataFrame({'x':x,'y':y})

sns.lineplot(x='x',y='y',data = df)

plt.show()

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x = 'bill_length_mm',y = 'body_mass_g' , data = df.head(100).dropna(),marker='o')
plt.show()

# %%
# Now here in above plot contain both male female responce.
# We can certainly figure out whichh is male and which is female.

We Can Exphasis plot based on One of the column of dataFrame.
We can do this using hue parameter

# %%
sns.lineplot(x = 'bill_length_mm',y = 'body_mass_g' , data = df.dropna(),marker='o' , hue = 'sex')
plt.show()

# Now we can easily do analysis as graph is seperated according to the sex.

# %%
# I can achive the same thing using pandas and matplotlib. 
# For that i need to seperate the data according to the gender.
# Then i need to plot 2 lineplots with blue and orange color.
df1 = df.dropna()
df1  = df1.sort_values(by = 'bill_length_mm')
group = df1.groupby('sex')
x1 = group.get_group('Male')['bill_length_mm']
y1 = group.get_group('Male')['body_mass_g']

x2 = group.get_group('Female')['bill_length_mm']
y2 = group.get_group('Female')['body_mass_g']


plt.plot(x1,y1,marker='o')
plt.plot(x2,y2,marker='o')
plt.show()


# Its a same graph but very lengthy code. 
# seaborn is lovely ;)

# %%
# When plot has different group formed using hue then we can use style to diffeentiat drawing style of different groups.
sns.lineplot(x = 'bill_length_mm',y = 'body_mass_g' , data = df.dropna(),marker='o' , hue = 'sex' , style = 'sex')
plt.show()

# %% [markdown]
# ## Changing color and marker style for different groups

# %%
# When plot has different group formed using hue then we can use style to diffeentiat drawing style of different groups.
sns.lineplot(x = 'bill_length_mm',y = 'body_mass_g' , data = df.dropna(),marker='o' , hue = 'sex' , style = 'sex',palette='Accent')
plt.show()

# %%
# Adding custom colors using palette
sns.lineplot(x = 'bill_length_mm',y = 'body_mass_g' , data = df.dropna(),marker='o' , hue = 'sex' , style = 'sex',palette = ['#53cedb','#72e885'])
plt.show()

# %% [markdown]
# # Bar Plot

# %%
# Bar plot is used to plot the catogorical data on the x axis .
# By default bar plot plots the mean on the y axis.
# Statistical function can be choosed using estimator attribute

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x = 'island',y = 'bill_length_mm',data = df)
plt.show()

# %%
sns.barplot(x = 'island',y = 'bill_length_mm',data = df, estimator = np.max , ci = 'sd')
# Errorbar indicates standard deviation.
# Now Y axis has max bill length for each catogory.
plt.show()

# %%
sns.barplot(x = 'island',y = 'bill_length_mm',data = df,hue = 'sex',width = 0.5)
plt.show()

# %%
# I can change the order of the bars as well.

order  = [ 'Dream' , 'Torgersen' , 'Biscoe' ] 
sns.barplot(x = 'island',y = 'bill_length_mm',data = df , order = order , hue = 'sex')
plt.show()

# %%
# I can even change the hue order.
sns.barplot(x = 'island',y = 'bill_length_mm',data = df , order = order , hue = 'sex', hue_order = ['Female','Male'],errorbar = None,width = 0.6,)
plt.legend(loc = "lower left")
plt.show()

# %%
# I can plot horizontal barplot using orient = 'h'

sns.barplot(x = 'flipper_length_mm' , y = 'bill_length_mm' , data = df.head(10) , orient = 'h',palette = ['#72e8e0'],width = 0.5)
plt.show()

# %% [markdown]
# # Histogram

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(x = 'bill_depth_mm' , data = df, bins = [10,12,14,16,18,20,22,24])
plt.show()

# %%
sns.histplot(x = 'bill_depth_mm' , data = df, bins = [10,12,14,16,18,20,22,24],kde = True)
# kde -> Kernel Density Estimation. 
plt.show()

# %%
sns.histplot(x = 'bill_depth_mm' , data = df, bins = [10,12,14,16,18,20,22,24],hue = 'sex')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# Lets check relation between bill length and body mass using scatter plot.

sns.scatterplot(x = 'bill_length_mm' , y = 'body_mass_g' , data  = df)
plt.show()

# %%
# lets differentiate data by sex.
sns.scatterplot(x = 'bill_length_mm' , y = 'body_mass_g' , data  = df , hue = 'sex')
plt.show()

# %%
# We can adjust size according to the size of data . 
# Lets we want size of each dot should depend on body mass . Higher the size and higher the mass.
sns.scatterplot(x = 'bill_length_mm' , y = 'body_mass_g' , data  = df , hue = 'sex' , size = 'body_mass_g')
# Bigger dots indicates the higher body mass
plt.show()

# %%
# We can adjust color palette using palette attribute. 
sns.scatterplot(x = 'bill_length_mm' , y = 'body_mass_g' , data  = df , hue = 'sex',palette = 'magma')
plt.show()

# %% [markdown]
# # HeatMap

# %%
# HeatMap should be used for those 2d data which has same type.
# e.g If we want to make heatmap of rates then every value should be rate . If we add other column whose values are not rate so this will
# make heatmap inaporopriate.

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
plt.figure(figsize = (8,6))
sample = df.drop(columns = ['species','island','sex']).dropna().corr()

sns.heatmap(sample,cmap = 'Blues',annot = True)
plt.tight_layout()
plt.show()
sample
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
flight = sns.load_dataset('flights')
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pivot = flight.pivot_table(index = 'month' , columns = 'year' , values = 'passengers')
pivot.astype(int)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize = (8,6))
sns.heatmap(pivot,cmap = 'Blues',linecolor = 'white',linewidth = 1)
plt.show()

# %% [markdown]
# # RugPlot

# %%
df = sns.load_dataset('planets')
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
plt.figure(figsize = (5,2))
sns.rugplot(x = 'mass' , data = df , height = 0.2)
# Out:
# C:\Users\katus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='mass'>

# %% [markdown]
# # Displot

# %%
df = sns.load_dataset('exercise')
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.set(style = 'whitegrid')
sns.displot(x = 'pulse' , data = df)

# %%
sns.set(style = "darkgrid")
sns.displot(x = 'pulse' , data = df , bins = 5)
plt.show()

# %% [markdown]
# # KDE Plot

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.kdeplot(x = 'pulse' , data = df , shade = True , label = 'pulse')
sns.kdeplot(x = 'id' , data = df , shade = True,label = 'id')
plt.legend()
plt.show()

# %% [markdown]
# # Count Plot

# %%
# X axis has the different categories 
# Y axis has the total count of each categories

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.countplot(x = 'diet' , data = df)
plt.show()

# %%
sns.countplot(x = 'diet' , data = df , width = 0.5 , hue = 'kind')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') ## This is used to move the legend outside the plot.
plt.show()

# %% [markdown]
# # Boxplot

# %%
# We use boxplot when x axis has different categories and y axis has continous data.
# When we want to compare the diffenrent categories we can use box plot.

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.boxplot(x = 'diet' , y = 'pulse' , data = df )
plt.show()

# %%
# We can easily interpret that low fat peoples has less median pulse rate. 
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) 

# Used to ignore the future warning

# %%
sns.boxplot(x = 'diet' , y = 'pulse' , data = df , hue = 'kind' )
plt.show()

# %% [markdown]
# # ViolinPlot

# %%
sns.violinplot(x = 'diet' , y = 'pulse' , data = df )
plt.show()

# %%
sns.violinplot(x = 'diet' , y = 'pulse' , data = df, hue = 'kind')
plt.show()

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x = 'diet' , y = 'pulse' , data = df )
plt.show()

# %% [markdown]
# # JOintPlot

# %%
# Jointplot is used to plot comparative plot . 
# We can see both scatter and histogram at the same time

# %%
df = sns.load_dataset('planets')
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.jointplot(x = 'mass' , y = 'distance' , data = df , hue = 'method')

# %%
# Problem with above graph is the range of values of y axis.
# LEts fix this by setting range.

# %%
z = sns.jointplot(x = 'mass' , y = 'distance' , data = df , hue = 'method')
z.ax_joint.set_ylim(bottom = 0 , top = df['distance'].max() / 10 )
# Out:
# (0.0, 850.0)

# %% [markdown]
# # Pairplot

# %%
# pairplot plot comparizon graph for all the numeric column. 
# SO we need to make sure we pass only the neccessay and required columns in pairplot

# %%
temp = df.drop(columns = ['method' , 'number' , 'year'])
temp = temp.dropna().head(50)

# %%
temp.head()
# Out:
#    orbital_period   mass  distance
# 0         269.300   7.10     77.40
# 1         874.774   2.21     56.95
# 2         763.000   2.60     19.84
# 3         326.030  19.40    110.62
# 4         516.220  10.50    119.47

# %%
sns.pairplot(temp)
# This plots scatterplot for all the numeric data

# %% [markdown]
# # HeatMap

# %%
df = pd.read_csv('Documents/country_table.csv')
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df1 = df.set_index('Countries')
df1
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# ...

# %%
sns.heatmap(data = df1)
# Out:
# <Axes: ylabel='Countries'>

# %%
# Problem with above heatmap is that column life expectacy is not rate which is plotting heatmap incorrect. 
# So lets remove that column
plt.figure(figsize = (7,4),dpi = 100)
sns.heatmap(data = df1.drop(columns = 'Life expectancy') , cmap = 'Blues',linecolor = 'white' , linewidth = 1 , annot = True ,annot_kws={"color": "black"} , fmt = '.2f')
# Now we can clearly see the heatmap
plt.show()

# %% [markdown]
# # CLustormap

# %%
# Clustermap use heatmap and tries to cluster the similar data together.

# %%
sns.clustermap(data = df1.drop(columns = 'Life expectancy') , linewidth = 1 , linecolor = 'white' , cmap = "viridis")
